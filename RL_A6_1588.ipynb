# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitha1588/Reinforcement-Learning/blob/main/RL_A6_1588.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
def random_agent(environment_name, episodes=5):

    env = gym.make(environment_name)
    print("\nEnvironment:", environment_name)
    print("--------------------------------")

    episode_rewards = []
    for episode in range(1, episodes + 1):

        state, info = env.reset()
        total_reward = 0
        steps = 0

        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1

            state = next_state

        average_reward = total_reward / steps

        episode_rewards.append(total_reward)

        print("Episode", episode)
        print("Total Reward:", total_reward)
        print("Steps:", steps)
        print("Average Reward:", round(average_reward, 2))
        print()
    overall_average = sum(episode_rewards) / len(episode_rewards)

    print("Total Rewards:", episode_rewards)
    print("Overall Average Reward:", round(overall_average, 2))

    env.close()

random_agent("CliffWalking-v1", episodes=5)
random_agent("Taxi-v4", episodes=5)
# Out:
# Environment: CliffWalking-v1
# --------------------------------
# Episode 1
# Total Reward: -89311
# Steps: 9022
# Average Reward: -9.9
#
# Episode 2
# Total Reward: -8533
# Steps: 811
# Average Reward: -10.52
#
# Episode 3
# Total Reward: -18044
# Steps: 1808
# Average Reward: -9.98
#
# Episode 4
# Total Reward: -37981
# Steps: 4222
# Average Reward: -9.0
#
# Episode 5
# Total Reward: -89491
# Steps: 7915
# Average Reward: -11.31
#
# Total Rewards: [-89311, -8533, -18044, -37981, -89491]
# Overall Average Reward: -48672.0
#
# Environment: Taxi-v4
# --------------------------------
# Episode 1
# Total Reward: -785
# Steps: 200
# Average Reward: -3.92
#
# Episode 2
# Total Reward: -803
# Steps: 200
# Average Reward: -4.01
#
# Episode 3
# Total Reward: -785
# Steps: 200
# Average Reward: -3.92
#
# Episode 4
# Total Reward: -740
# Steps: 200
# Average Reward: -3.7
#
# Episode 5
# Total Reward: -605
# Steps: 200
# Average Reward: -3.02
#
# Total Rewards: [-785, -803, -785, -740, -605]
# Overall Average Reward: -743.6
